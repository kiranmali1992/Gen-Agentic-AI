# %%
# Agentic Ai

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="deepseek-r1-distill-llama-70b",
    temperature=0
)
response = llm.invoke("capital of china")

# %%
response.content
# Out:
# '<think>\n\n</think>\n\nThe capital of China is **Beijing**.'
